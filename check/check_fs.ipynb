# %%
import matplotlib.pyplot as plt
import numpy as np
import teneva


from ttopt import TTOpt
from ttopt import ttopt_init

np.random.seed(16333)

# %%
d = 10
p = 2
q = 25
evals = 1.E+5
rmax = 4
reps = 10
fs_opt_list = [None, 0.001, 0.01, 0.1, 1., 10., 100, 1000.]
e_list = {}

# %%
for func in teneva.func_demo_all(d=d):
    lim = func.b[0] - func.a[0]
    e_list[func.name] = []
    for fs_opt in fs_opt_list:
        e = []
        for i in range(reps):
            name = func.name + ' ' * (15 - len(func.name))
            
            tto = TTOpt(f=func.get_f_poi, d=func.d, a=func.a, b=func.b,
                name=name, x_min_real=func.x_min, y_min_real=func.y_min,
                p=p, q=q, evals=evals)
            
            tto.minimize(rmax=rmax, fs_opt=fs_opt or None)
            e.append(tto.e_y)
            
            print(tto.info(with_e_x=False) + f' | {lim:-6.2f} | opt = {fs_opt}')
        
        e_list[func.name].append(np.mean(e))
        
        print('')
    
    print('\n')
# Out:
# Ackley         -10d | k=1.00e+05 | t_all=1.34e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.29e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.31e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.39e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.45e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.36e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.32e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.34e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.33e+00 | e_y=3.91e-06  |  65.54 | opt = None
# Ackley         -10d | k=1.00e+05 | t_all=1.29e+00 | e_y=3.91e-06  |  65.54 | opt = None
#
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.31e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.32e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
# Ackley         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.91e-06  |  65.54 | opt = 0.001
#
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.43e-01  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.29e-02  |  65.54 | opt = 0.01
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.01
#
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.45e-03  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.30e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 0.1
#
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1.0
#
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 10.0
#
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.91e-06  |  65.54 | opt = 100
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 100
#
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
# Ackley         -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.91e-06  |  65.54 | opt = 1000.0
#
#
#
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.76e-06  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=5.92e-07  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.87e-06  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.02e-05  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=8.65e-07  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.10e-06  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.62e-05  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.45e-06  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.88e-06  |  20.00 | opt = None
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.41e-06  |  20.00 | opt = None
#
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=3.54e-06  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.91e-05  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.71e-07  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.68e-05  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.44e-05  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=9.72e-06  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.68e-06  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.90e-06  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.94e-05  |  20.00 | opt = 0.001
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=6.03e-05  |  20.00 | opt = 0.001
#
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.59e-05  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=9.77e-06  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=8.89e-06  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.27e-04  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=9.41e-07  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.30e-05  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.30e-06  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=1.05e-05  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=9.41e-07  |  20.00 | opt = 0.01
# Alpine         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.64e-06  |  20.00 | opt = 0.01
#
# Alpine         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.42e-06  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=7.89e-06  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.83e-06  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.34e+00 | e_y=5.86e-06  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.07e-05  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.84e-05  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.76e-06  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.01e-05  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.43e-05  |  20.00 | opt = 0.1
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.53e-06  |  20.00 | opt = 0.1
#
# Alpine         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.93e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.85e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.57e-06  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.88e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=8.05e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.52e-06  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=5.43e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.71e-06  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=5.25e-07  |  20.00 | opt = 1.0
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.29e-05  |  20.00 | opt = 1.0
#
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.93e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.88e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=5.48e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.93e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.90e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.55e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.71e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.93e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.95e-07  |  20.00 | opt = 10.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=5.20e-07  |  20.00 | opt = 10.0
#
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.80e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.80e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.93e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.78e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.04e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.88e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.75e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.09e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.78e-07  |  20.00 | opt = 100
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.78e-07  |  20.00 | opt = 100
#
# Alpine         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.80e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.83e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.80e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.80e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.83e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.78e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.80e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.75e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.73e-07  |  20.00 | opt = 1000.0
# Alpine         -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=9.36e-07  |  20.00 | opt = 1000.0
#
#
#
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.81e-03  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.32e-08  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.79e-04  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.96e-05  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.23e-11  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.90e-04  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=1.62e-02  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.88e-04  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.03e-03  |   5.00 | opt = None
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=1.95e-06  |   5.00 | opt = None
#
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.03e-07  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.45e-02  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.12e-02  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=7.49e-09  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.34e+00 | e_y=1.26e-01  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.50e-04  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.54e-03  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.39e-03  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.96e-09  |   5.00 | opt = 0.001
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.19e-04  |   5.00 | opt = 0.001
#
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.56e-02  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.09e-01  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.08e-03  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=8.30e-03  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.30e+00 | e_y=3.06e-05  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.29e+00 | e_y=4.92e-04  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.02e-04  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.85e+00  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.06e-05  |   5.00 | opt = 0.01
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=9.57e-03  |   5.00 | opt = 0.01
#
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.19e-07  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.84e-03  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=4.88e-04  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.45e-03  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=1.49e-08  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.07e-03  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.64e-02  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=2.46e-07  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.90e-04  |   5.00 | opt = 0.1
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.13e-10  |   5.00 | opt = 0.1
#
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=2.44e-04  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.50e-09  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.95e-11  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.01e-02  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=9.88e-03  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.80e-08  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.06e-04  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=5.49e-04  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.96e-04  |   5.00 | opt = 1.0
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.27e-07  |   5.00 | opt = 1.0
#
# Brown          -10d | k=1.00e+05 | t_all=1.36e+00 | e_y=1.23e-07  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=4.90e-04  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.19e-07  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=8.70e-14  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.71e-13  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=2.56e-05  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=6.11e-03  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=5.04e-04  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=7.42e-06  |   5.00 | opt = 10.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.05e-05  |   5.00 | opt = 10.0
#
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.91e-06  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.34e-07  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.60e-14  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.60e-14  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=7.94e-09  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.12e-05  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=6.23e-06  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.05e-05  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.71e-06  |   5.00 | opt = 100
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.19e-07  |   5.00 | opt = 100
#
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.25e-01  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=8.77e-09  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.60e-14  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.60e-14  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.34e-07  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.60e-14  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=8.11e-06  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.19e-08  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.67e-05  |   5.00 | opt = 1000.0
# Brown          -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.23e-07  |   5.00 | opt = 1000.0
#
#
#
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.55e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.12e+00  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.67e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.44e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.89e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.54e+00  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.25e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.63e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.40e-01  |  20.00 | opt = None
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.90e-01  |  20.00 | opt = None
#
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.67e-01  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.63e+00  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.37e+00  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.44e+00  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.71e+00  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.71e-01  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.05e+00  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.08e-01  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.67e-01  |  20.00 | opt = 0.001
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.88e-01  |  20.00 | opt = 0.001
#
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.19e+00  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=7.82e-01  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.89e-01  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.64e+00  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=6.67e-01  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=6.67e-01  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.23e+00  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.73e+00  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.10e+00  |  20.00 | opt = 0.01
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.43e+00  |  20.00 | opt = 0.01
#
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.11e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.17e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.11e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.51e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.98e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.67e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.27e-01  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.64e+00  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.01e+00  |  20.00 | opt = 0.1
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.67e-01  |  20.00 | opt = 0.1
#
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.23e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.29e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.96e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.38e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.70e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.45e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.03e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.85e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.76e-01  |  20.00 | opt = 1.0
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.78e-01  |  20.00 | opt = 1.0
#
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.37e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.04e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.77e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.68e-01  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.15e-01  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.85e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.04e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.98e-01  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.40e+00  |  20.00 | opt = 10.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.26e-01  |  20.00 | opt = 10.0
#
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.77e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.39e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.07e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.11e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.73e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.69e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.01e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.41e+00  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.86e+01  |  20.00 | opt = 100
# Dixon          -10d | k=1.00e+05 | t_all=1.29e+00 | e_y=2.70e+00  |  20.00 | opt = 100
#
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.17e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.62e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.76e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.14e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=5.06e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.80e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.09e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.38e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.20e+00  |  20.00 | opt = 1000.0
# Dixon          -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.35e+01  |  20.00 | opt = 1000.0
#
#
#
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.19e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = None
#
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=3.64e-14  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=1.51e-14  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=7.99e-15  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.50e-13  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=7.99e-15  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=8.26e-14  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 0.001
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.51e-14  |   2.00 | opt = 0.001
#
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=7.99e-15  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=6.84e-14  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.99e-15  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.58e-14  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.58e-14  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=7.99e-15  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=1.04e-13  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.51e-14  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=7.99e-15  |   2.00 | opt = 0.01
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.58e-14  |   2.00 | opt = 0.01
#
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 0.1
# Exponential    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=7.99e-15  |   2.00 | opt = 0.1
#
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1.0
#
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.19e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 10.0
#
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 100
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 100
#
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
# Exponential    -10d | k=1.00e+05 | t_all=1.20e+00 | e_y=4.44e-15  |   2.00 | opt = 1000.0
#
#
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.41e-06  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.12e-01  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.03e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.18e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.74e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.90e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.59e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.82e-02  | 1200.00 | opt = None
# Grienwank      -10d | k=1.00e+05 | t_all=1.30e+00 | e_y=3.19e-02  | 1200.00 | opt = None
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=8.97e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.98e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.48e-02  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=8.13e-10  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.93e-01  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.44e-02  | 1200.00 | opt = 0.001
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.001
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.21e-02  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.48e-02  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.94e-01  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.49e-01  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.19e-01  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.86e-02  | 1200.00 | opt = 0.01
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.01
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.48e-02  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.69e-10  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.09e-01  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.91e-01  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.82e-02  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.72e-02  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.31e-01  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=2.21e-02  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.62e-02  | 1200.00 | opt = 0.1
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.15e-02  | 1200.00 | opt = 0.1
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.51e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.93e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.15e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.76e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.48e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.97e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.58e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.97e-02  | 1200.00 | opt = 1.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.23e-02  | 1200.00 | opt = 1.0
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.43e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.94e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.40e-03  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.23e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=2.96e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.46e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.20e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.69e-10  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.18e-02  | 1200.00 | opt = 10.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.45e-02  | 1200.00 | opt = 10.0
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=2.71e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.71e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.94e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.48e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.94e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.48e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.38e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.68e-02  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.94e-01  | 1200.00 | opt = 100
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.18e-02  | 1200.00 | opt = 100
#
# Grienwank      -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.68e-08  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.69e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.64e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.43e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.72e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.97e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.18e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.92e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.23e-02  | 1200.00 | opt = 1000.0
# Grienwank      -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.13e-02  | 1200.00 | opt = 1000.0
#
#
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.30e-01  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.11e-02  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=8.38e-02  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.13e-02  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=4.91e-03  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.77e-02  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=7.50e-03  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=4.25e-02  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.93e-03  |   3.14 | opt = None
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.07e-02  |   3.14 | opt = None
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.16e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.04e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=9.20e-02  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.48e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=6.27e-02  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.45e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.93e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.14e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.88e-01  |   3.14 | opt = 0.001
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.69e-01  |   3.14 | opt = 0.001
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.29e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.26e-02  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.71e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=3.71e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.12e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.33e+00 | e_y=1.17e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.29e+00 | e_y=3.07e-01  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.42e-06  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=4.70e-02  |   3.14 | opt = 0.01
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=3.76e-02  |   3.14 | opt = 0.01
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.83e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.91e-03  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.57e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.10e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.80e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.25e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.09e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.97e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=2.37e-01  |   3.14 | opt = 0.1
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=8.89e-02  |   3.14 | opt = 0.1
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=5.08e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.34e+00 | e_y=4.91e-03  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.69e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.07e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.04e-01  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=1.50e-01  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.48e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=4.56e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.48e-02  |   3.14 | opt = 1.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.07e-02  |   3.14 | opt = 1.0
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.91e-03  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.76e-02  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.91e-03  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.72e-06  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.72e-06  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.62e-06  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.24e-06  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.27e+00 | e_y=4.11e-02  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.71e-06  |   3.14 | opt = 10.0
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.69e-06  |   3.14 | opt = 10.0
#
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.72e-06  |   3.14 | opt = 100
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.71e-06  |   3.14 | opt = 100
# Michalewicz    -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.90e-01  |   3.14 | opt = 100
# ...
#
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.97e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.31e+00 | e_y=3.53e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.10e+00  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.80e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.03e+00  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.42e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.00e+00  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.38e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.34e-01  |   4.10 | opt = 100
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.52e-01  |   4.10 | opt = 100
#
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.02e+00  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.34e+00  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.56e-01  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.15e+00  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.44e+01  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.15e-01  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.16e+00  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.79e+00  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=4.97e-01  |   4.10 | opt = 1000.0
# Rosenbrock     -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.94e+00  |   4.10 | opt = 1000.0
#
#
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.03e-02  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.95e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.32e+00 | e_y=2.31e-06  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=4.35e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=3.59e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.31e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.15e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.05e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.99e-01  | 200.00 | opt = None
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.56e-02  | 200.00 | opt = None
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.50e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.75e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.52e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.14e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.53e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.84e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.90e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.96e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.02e-01  | 200.00 | opt = 0.001
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.18e-01  | 200.00 | opt = 0.001
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.41e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.00e+00  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=2.65e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.04e+00  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=7.30e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.93e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.55e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=8.02e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=6.19e-01  | 200.00 | opt = 0.01
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=7.31e-01  | 200.00 | opt = 0.01
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.46e-02  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.10e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.25e+00  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.87e-02  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.37e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.63e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.47e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.03e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.61e-01  | 200.00 | opt = 0.1
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.83e-01  | 200.00 | opt = 0.1
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.81e-01  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=7.07e-02  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.03e-01  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.19e-02  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.97e-01  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=1.09e-01  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=5.07e-02  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.93e-02  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=8.22e-07  | 200.00 | opt = 1.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=9.82e-02  | 200.00 | opt = 1.0
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=8.20e-02  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.67e-02  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.91e-07  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.66e-01  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.60e-10  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.60e-10  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.98e-02  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.07e-02  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=4.36e-01  | 200.00 | opt = 10.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=9.16e-02  | 200.00 | opt = 10.0
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.13e-01  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.12e-02  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.96e-02  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.66e-01  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=8.83e-02  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.53e-01  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.09e-02  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.98e-04  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.25e-01  | 200.00 | opt = 100
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.30e-02  | 200.00 | opt = 100
#
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=8.97e-02  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=8.79e-02  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.95e-01  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=8.02e-02  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=9.02e-02  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=9.27e-02  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=5.05e-01  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.16e-01  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=3.35e-01  | 200.00 | opt = 1000.0
# Schaffer       -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=8.33e-02  | 200.00 | opt = 1000.0
#
#
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.25e+00 | e_y=7.51e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.51e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.38e-03  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.28e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.04e-01  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.38e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.51e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.62e-04  | 1000.00 | opt = None
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.62e-04  | 1000.00 | opt = None
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=4.16e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.09e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.70e+01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=3.12e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.09e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.08e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.12e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=3.13e+00  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.08e-01  | 1000.00 | opt = 0.001
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=5.19e-01  | 1000.00 | opt = 0.001
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.28e+00 | e_y=3.11e-01  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=2.64e-03  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.31e-01  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.09e-01  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.38e-03  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.27e-03  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.62e-03  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.37e-03  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.05e-01  | 1000.00 | opt = 0.01
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.10e-01  | 1000.00 | opt = 0.01
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.39e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.60e-04  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.63e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.39e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.51e-04  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.39e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.02e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.01e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.62e-03  | 1000.00 | opt = 0.1
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=2.00e-03  | 1000.00 | opt = 0.1
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.51e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.27e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.51e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.39e-03  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.27e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.38e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.62e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.51e-04  | 1000.00 | opt = 1.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=7.51e-04  | 1000.00 | opt = 1.0
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.38e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.43e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=7.62e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.32e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.40e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.27e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.38e-04  | 1000.00 | opt = 10.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.27e-04  | 1000.00 | opt = 10.0
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.31e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.26e+00 | e_y=1.49e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.23e+00 | e_y=1.27e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.03e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=1.27e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.27e-04  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.24e+00 | e_y=6.85e+01  | 1000.00 | opt = 100
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.04e-01  | 1000.00 | opt = 100
#
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.04e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.04e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=4.15e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=2.07e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=3.11e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.04e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.21e+00 | e_y=1.30e-04  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.04e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=2.07e-01  | 1000.00 | opt = 1000.0
# Schwefel       -10d | k=1.00e+05 | t_all=1.22e+00 | e_y=1.55e-04  | 1000.00 | opt = 1000.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plt.subplots_adjust(wspace=0.3)

ax.set_xlabel('Parameter in smoothing function')
ax.set_ylabel('Relative error')
    
for name, res in e_list.items():
    ax.plot([0.000001] + fs_opt_list[1:], res, label=name, marker='s', markersize=5, linewidth=3)
    
ax.semilogx()
ax.semilogy()
ax.legend(loc='best', frameon=True)
ax.grid(ls=":")

plt.show()
